# %%
# ai 女友

class GirlFriend:
    def __init__(self, name, height, weight,skin, hair):
        self.name = name #屬性 => 名字
        self.height = height #屬性 => 身高
        self.weight = weight #屬性 => 體重
        self.skin = skin #屬性 => 膚色
        self.hair = hair #屬性 => 髮型

    def fight(): #function
        print("好啊 來吵架")
        
    def cry():
        print("Q......Q")
        
    def spend_money():
        print("拿錢來")

# %%
小老婆1號 = GirlFriend("Gracie", 170, 60, "white", "brown") #instances 初始化成一個物件
小老婆2號 = GirlFriend("Megan", 180, 65, "white", "gold") #instances 初始化成一個物件
小老婆3號 = GirlFriend("Amy", 165, 55, "yellow", "black") #instances 初始化成一個物件

# %%
小老婆1號.name
# Out:
# 'Gracie'

# %%
小老婆2號.height
# Out:
# 180

# %%
小老婆3號.hair
# Out:
# 'black'
