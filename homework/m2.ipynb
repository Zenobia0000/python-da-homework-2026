# %%
# Out:
# 30.0

# %%
# Out:
# array([ 20,  40,  60,  80, 100])

# %%
# Out:
# array([30, 40, 50])

# %%
# Out:
# '單價大於1000的商品共有 = 16 件'

# %%
# Out:
# '庫存最多 = [10  0 17] '

# %%
# Out:
# np.float64(1203000.0)
